# %% [markdown]
# # **Lab 2: DataFrames**
#
# Lecturer: `Sirasit Lochanachit`
#
#
# Course: `06026213 Big Data Systems`
#
# Term: `02/2025`
#
# Lab materials prepared by `Sasithorn (TA)`

# %% [markdown]
# Requirements
# - Unity Catalog ต้องใช้งานได้ (โดย default สามารถใช้ได้อยู่แล้ว)
# - ต้องสร้าง Volume มาเก็บข้อมูลที่ใช้ใน Lab นี้ (tutorial)
# - ต้องมีสิทธิ์เหล่านี้ใน Unity Catalog :  READ VOLUME and WRITE VOLUME, use schema, use catalog or ALL PRIVILEGES สำหรับ Volume, Schema, Catalog ที่ใช้

# %% [markdown]
# ## Step 0: Create new volume
#
# สร้าง Notebook ใหม่ จากนั้น Create Volume "tutorial"

# %%
# %sql
create volume if not exists tutorial

# %% [markdown]
# ## Step 1: Define variables and load CSV file

# %%
catalog = "workspace"
schema = "default"
volume = "tutorial"
download_url = "https://health.data.ny.gov/api/views/jxy9-yhdk/rows.csv"
file_name = "rows.csv"
table_name = "baby"
path_volume = "/Volumes/" + catalog + "/" + schema + "/" + volume
path_table = catalog + "." + schema
print(path_table) # Show the complete path
print(path_volume) # Show the complete path

# %% [markdown]
# Download csv files and save into "tutorial" volume

# %%
dbutils.fs.cp(f"{download_url}", f"{path_volume}/{file_name}")

# %% [markdown]
# ## Step 1: Create a DataFrame

# %% [markdown]
# Apache Spark DataFrames
#
# - ในส่วนของ Apache Spark DataFrames มี function ที่มากมาย ซึ่งช่วยในการทำ data analysis ได้ ex: select columns, filter, join, aggregate
# - สร้างบน RDDs
# - มีประสิทธิภาพสูง เพราะใช้ unified planning and optimization engine กับ Spark DF & Spark SQL ก็จะได้ประสิทธิภาพที่เกือบจะเหมือนกันในทุกภาษาที่ DataBricks รองรับ(Python, SQL, Scala, R)

# %%
data = [[2021, "test", "Albany", "M", 42]]
columns = ["Year", "First_Name", "County", "Sex", "Count"]

df1 =

# %% [markdown]
# display() method is specific to Databricks notebooks and provides a richer visualization.

# %%
display(df1)

# %% [markdown]
# The show() method is a part of the Apache Spark DataFrame API and provides basic visualization.

# %%
df1.show()

# %% [markdown]
# ## Step 2: Load data into a DataFrame from CSV file

# %%
df_csv = 
display(df_csv)

# %% [markdown]
# ## Step 3: View and interact with your DataFrame

# %% [markdown]
# View Schema in both DataFrames

# %%
df_csv.printSchema()
df1.printSchema()

# %% [markdown]
# Schema ของทั้ง 2 DataFrame เหมือนกัน ยกเว้น field "First_Name"

# %% [markdown]
# Rename Column

# %%
df_csv = df_csv.withColumnRenamed("First Name", "First_Name")
df_csv.printSchema

# %% [markdown]
# Union 2 DataFrames with same schema (i.e. concatenate)

# %%
df = df1.union(df_csv)
display(df)
df.printSchema

# %% [markdown]
# Filter rows in DataFrame

# %% [markdown]
# filter() method

# %%
display(df.filter(df["Count"] > 50))

# %% [markdown]
# where() method

# %%
display(df.where(df["Count"] > 50))

# %% [markdown]
# Select some columns

# %%
from pyspark.sql.functions import desc
display(df.select("First_Name", "Count").orderBy(desc("Count")))

# %% [markdown]
# Create a Subset DaraFrame

# %% [markdown]
# สร้าง DataFrame โดย filter ข้อมูลตามปี จำนวน และเพศ

# %%
subsetDF = 
display(subsetDF)

# %% [markdown]
# Number of Rows in DataFrame

# %%
df.count()

# %% [markdown]
# ## Step 4: Save the DataFrame

# %% [markdown]
# Save DataFrame to Table

# %% [markdown]
#  สามารถแวะไปดู Table ตาม path ที่เรากำหนดไว้ตามปกติ ซึ่งตัวแปร path และชื่อ Table เราตั้งตัวแปรไว้แล้วตั้งแต่แรก

# %% [markdown]
# Save DataFrame to JSON Files

# %% [markdown]
# ## Step 5: Read DataFrame from JSON file

# %% [markdown]
# ---
